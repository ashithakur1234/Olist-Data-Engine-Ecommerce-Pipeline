# %%
import pandas as pd
customers= pd.read_csv(r"C:\Users\pc\OneDrive\Desktop\\olist  braziliain e-commerce project\Data\olist_customers_dataset.csv")
order_items= pd.read_csv(r"C:\Users\pc\OneDrive\Desktop\\olist  braziliain e-commerce project\Data\olist_order_items_dataset.csv")
order_payments= pd.read_csv(r"C:\Users\pc\OneDrive\Desktop\\olist  braziliain e-commerce project\Data\olist_order_payments_dataset.csv")
order_reviews= pd.read_csv(r"C:\Users\pc\OneDrive\Desktop\\olist  braziliain e-commerce project\Data\olist_order_reviews_dataset.csv")
orders= pd.read_csv(r"C:\Users\pc\OneDrive\Desktop\\olist  braziliain e-commerce project\Data\olist_orders_dataset.csv")
products= pd.read_csv(r"C:\Users\pc\OneDrive\Desktop\\olist  braziliain e-commerce project\Data\olist_products_dataset.csv")
print("this is customers table")
print(customers.shape)
print(customers.head())
print("\nthis is order_items table")
print(order_items.shape)
print(order_items.head())
print("\nthis is order_payments table")
print(order_payments.shape)
print(order_payments.head())
print("\nthis is order_reviews table")
print(order_reviews.shape)
print(order_reviews.head())
print("\nthis is orders table")
print(orders.shape)
print(orders.head())
print("\nthis is products table")
print(products.shape)
print(products.head())
# Out:
# this is customers table
# (99441, 5)
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
# this is order_items table
# (112650, 7)
#                            order_id  order_item_id  \
# ...

# %%
print ("Total Row&Columns:", df.shape)
print("\Customers Column Names:")
for col in df.columns:
    print("->",col)
print ("\nTotal Row&Columns:", order_items.shape)
print("\order_items Column Names:")
for col in order_items.columns:
    print("->",col)
print ("\nTotal Row&Columns:", order_payments.shape)
print("\order_payments Column Names:")
for col in order_payments.columns:
    print("->",col)
print ("\nTotal Row&Columns:", order_reviews.shape)
print("\order_reviews Column Names:")
for col in order_reviews.columns:
    print("->",col)
print ("\nTotal Row&Columns:", orders.shape)
print("\orders Column Names:")
for col in orders.columns:
    print("->",col)
print ("\nTotal Row&Columns:", products.shape)
print("\products Column Names:")
for col in products.columns:
    print("->",col)
# Out:
# Total Row&Columns: (99441, 5)
# \Customers Column Names:
# -> customer_id
# -> customer_unique_id
# -> customer_zip_code_prefix
# -> customer_city
# -> customer_state
#
# Total Row&Columns: (112650, 7)
# \order_items Column Names:
# -> order_id
# -> order_item_id
# -> product_id
# -> seller_id
# -> shipping_limit_date
# -> price
# -> freight_value
#
# Total Row&Columns: (103886, 5)
# \order_payments Column Names:
# -> order_id
# -> payment_sequential
# -> payment_type
# -> payment_installments
# -> payment_value
#
# Total Row&Columns: (99224, 7)
# \order_reviews Column Names:
# -> review_id
# -> order_id
# -> review_score
# -> review_comment_title
# -> review_comment_message
# -> review_creation_date
# -> review_answer_timestamp
#
# Total Row&Columns: (99441, 8)
# \orders Column Names:
# -> order_id
# -> customer_id
# -> order_status
# -> order_purchase_timestamp
# -> order_approved_at
# -> order_delivered_carrier_date
# -> order_delivered_customer_date
# ...

# %%
print("Data Types:")
print(customers.dtypes)
print("Data Types:")
print(order_items.dtypes)
print("Data Types:")
print(order_payments.dtypes)
print("Data Types:")
print(order_reviews.dtypes)
print("Data Types:")
print(orders.dtypes)
print("Data Types:")
print(products.dtypes)
# Out:
# Data Types:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object
# Data Types:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object
# Data Types:
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object
# Data Types:
# review_id                  object
# order_id                   object
# review_score                int64
# review_comment_title       object
# review_comment_message     object
# review_creation_date       object
# review_answer_timestamp    object
# dtype: object
# Data Types:
# ...

# %%
print(customers.isnull().sum())
print(order_items.isnull().sum())
print(order_payments.isnull().sum())
print(order_reviews.isnull().sum())
print(orders.isnull().sum())
print(products.isnull().sum())
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# ...
